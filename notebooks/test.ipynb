# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("postgresql://postgres:Database_23@localhost:5432/data_pipeline")

ord = pd.read_sql_table("fact_orders", engine)

ord
# Out:
#              order_id  customer_id     order_timestamp        category  \
# 0        ORD000431201  CUST0049999 2022-08-11 22:16:00     Electronics
# 1        ORD000431202  CUST0049995 2022-10-29 20:14:00          Sports
# 2        ORD000431203  CUST0049865 2024-07-21 22:31:00         Fashion
# 3        ORD000431204  CUST0049999 2022-12-13 18:10:00         Fashion
# 4        ORD000431205  CUST0050000 2023-06-08 20:35:00           Books
# ...               ...          ...                 ...             ...
# 1499995  ORD000431196  CUST0049600 2024-07-27 13:38:00  Home & Kitchen
# 1499996  ORD000431197  CUST0049707 2021-01-01 12:10:00         Fashion
# 1499997  ORD000431198  CUST0050000 2023-07-24 10:19:00  Home & Kitchen
# 1499998  ORD000431199  CUST0049998 2021-04-29 08:18:00     Electronics
# 1499999  ORD000431200  CUST0048877 2021-03-10 18:43:00           Books
#
#                 product_name  final_amount  shipping_cost  total_revenue  \
# ...

# %%
cust = pd.read_sql_table("dim_customers", engine)
cust
# Out:
#        customer_id       full_name       city  age   gender customer_segment  \
# 0      CUST0000001    Vikram Singh  Hyderabad   27   Female         Inactive
# 1      CUST0000002     Kevin Young      Delhi   31     Male          Regular
# 2      CUST0000003     David Smith  Bangalore   32  Unknown         Inactive
# 3      CUST0000004      Fatima Lee     Nagpur   23    Other          Regular
# 4      CUST0000005    Fatima Menon      Delhi   44     Male          Premium
# ...            ...             ...        ...  ...      ...              ...
# 49995  CUST0049996      Shreya Lee     Mumbai   27    Other          Regular
# 49996  CUST0049997      Mia Sharma       Pune   31   Female          Premium
# 49997  CUST0049998  Arjun Williams       Pune   44   Female         Inactive
# 49998  CUST0049999    Kavya Sharma      Surat   40     Male          Premium
# 49999  CUST0050000  Maria Thompson      Delhi   32     Male          Regular
#
# ...

# %%
df = pd.merge(ord, cust, on="customer_id", how="inner")

df
# Out:
#              order_id  customer_id     order_timestamp        category  \
# 0        ORD000431201  CUST0049999 2022-08-11 22:16:00     Electronics
# 1        ORD000431202  CUST0049995 2022-10-29 20:14:00          Sports
# 2        ORD000431203  CUST0049865 2024-07-21 22:31:00         Fashion
# 3        ORD000431204  CUST0049999 2022-12-13 18:10:00         Fashion
# 4        ORD000431205  CUST0050000 2023-06-08 20:35:00           Books
# ...               ...          ...                 ...             ...
# 1499995  ORD000431196  CUST0049600 2024-07-27 13:38:00  Home & Kitchen
# 1499996  ORD000431197  CUST0049707 2021-01-01 12:10:00         Fashion
# 1499997  ORD000431198  CUST0050000 2023-07-24 10:19:00  Home & Kitchen
# 1499998  ORD000431199  CUST0049998 2021-04-29 08:18:00     Electronics
# 1499999  ORD000431200  CUST0048877 2021-03-10 18:43:00           Books
#
#                 product_name  final_amount  shipping_cost  total_revenue  \
# ...

# %%
query = "Select * from fact_orders inner join dim_customers using (customer_id)"

table = pd.read_sql_query(query, engine)

table
# Out:
#          customer_id      order_id     order_timestamp        category  \
# 0        CUST0049999  ORD000431201 2022-08-11 22:16:00     Electronics
# 1        CUST0049995  ORD000431202 2022-10-29 20:14:00          Sports
# 2        CUST0049865  ORD000431203 2024-07-21 22:31:00         Fashion
# 3        CUST0049999  ORD000431204 2022-12-13 18:10:00         Fashion
# 4        CUST0050000  ORD000431205 2023-06-08 20:35:00           Books
# ...              ...           ...                 ...             ...
# 1499995  CUST0048755  ORD000431152 2024-04-20 15:25:00         Grocery
# 1499996  CUST0042459  ORD000431170 2020-07-26 09:03:00     Electronics
# 1499997  CUST0049507  ORD000431187 2021-11-30 10:52:00     Electronics
# 1499998  CUST0049697  ORD000431191 2021-12-13 12:40:00  Home & Kitchen
# 1499999  CUST0049600  ORD000431196 2024-07-27 13:38:00  Home & Kitchen
#
#               product_name  final_amount  shipping_cost  total_revenue  \
# ...

# %%
path =
